# %%
# Importing necessary packages

import pandas as pd
import numpy as np
import missingno as msno

# %%
# Read CSV file and call it df
df_original = pd.read_csv('Boston Housing Data.csv')

# %%
# Prints out first 5 records in dataframe
df_original.head(5)
# Out:
#    locationid     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0         101  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900  NaN
# 1         102  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671  NaN
# 2         103  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671  2.0
# 3         104  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622  NaN
# 4         105  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622  3.0
#
#    tax  ptratio  lstat  medv date_appraised locationzone locationdistrict
# 0  296     15.3   4.98  24.0      3/27/2016           N3                N
# 1  242     17.8   9.14  21.6      3/28/2016           B2                B
# 2  242     17.8   4.03  34.7      3/27/2016           G3                G
# 3  222     18.7   2.94  33.4      3/26/2016           D2                D
# 4  222     18.7   5.33  36.2      3/28/2016           M3                M

# %%
# Show general info of dataframe
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   locationid        508 non-null    int64
#  1   crim              508 non-null    float64
#  2   zn                508 non-null    float64
#  3   indus             508 non-null    float64
#  4   chas              508 non-null    int64
#  5   nox               508 non-null    float64
#  6   rm                508 non-null    float64
#  7   age               508 non-null    float64
#  8   dis               508 non-null    float64
#  9   rad               300 non-null    float64
#  10  tax               508 non-null    int64
#  11  ptratio           508 non-null    float64
#  12  lstat             508 non-null    float64
#  13  medv              508 non-null    float64
#  14  date_appraised    508 non-null    object
#  15  locationzone      508 non-null    object
# ...

# %% [markdown]
# ### As shown above, there are 0 non-null values in the dataset

# %% [markdown]
# # I) First checking dataset for duplicates

# %%
# Check for duplicate values and their counts
df_original.duplicated().value_counts()
# Out:
# False    507
# True       1
# dtype: int64

# %% [markdown]
# ### There are duplicated values with a total count of 1

# %%
# Dropping all duplicates and saving to new df
df_no_duplicates = df_original.drop_duplicates()

# %%
# Checking again if duplicates exist
df_no_duplicates.duplicated().value_counts()
# Out:
# False    507
# dtype: int64

# %% [markdown]
# # II) Checking for missing values

# %%
# Check to see if there are null values
df_original.isnull().sum()
# Out:
# locationid            0
# crim                  0
# zn                    0
# indus                 0
# chas                  0
# nox                   0
# rm                    0
# age                   0
# dis                   0
# rad                 208
# tax                   0
# ptratio               0
# lstat                 0
# medv                  0
# date_appraised        0
# locationzone          0
# locationdistrict      1
# dtype: int64

# %%
# Using visuals to see missing data, if any
msno.matrix(df_original, fontsize=12, labels=True)
# Out:
# <AxesSubplot: >
